# %%
import pandas as pd
df = pd.read_json('/home/vigith/dynadojo/docs/dyna_complexity_data.JSON', orient='records', lines=True)
df
# Out:
#                   system  D  seed  \
# 0                 Aizawa  3     1
# 1                 Aizawa  3     1
# 2    AnishchenkoAstakhov  3     1
# 3    AnishchenkoAstakhov  3     1
# 4                Arneodo  3     1
# ..                   ... ..   ...
# 249               YuWang  3     1
# 250              YuWang2  3     1
# 251              YuWang2  3     1
# 252             ZhouChen  3     1
# 253             ZhouChen  3     1
#
#                                                     x0    OOD  timesteps  \
# 0    [-0.7714825128, -0.6565881090000001, -0.158586...  False        100
# 1    [-0.7714825128, -0.6565881090000001, -0.158586...   True        100
# 2     [3.5624624915, 3.4690454262, 1.7976284685000001]  False        100
# 3     [3.5624624915, 3.4690454262, 1.7976284685000001]   True        100
# 4          [-2.7059058508, 0.1992056825, 3.1234059944]  False        100
# ..                                                 ...    ...        ...
# ...
