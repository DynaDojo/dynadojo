# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dynadojo.systems.lds import LDSystem
from dynadojo.baselines.dnn import DNN
from dynadojo.challenges import FixedTrainSize

# %%
challenge = FixedTrainSize(
    n=100,
    L=[2, 3, 4, 5],
    E=None,
    t=50,
    control_horizons=0,
    max_control_cost_per_dim=0,
    system_cls=LDSystem,
    trials=10,
    test_examples=50,
    test_timesteps=50,
)
data = challenge.evaluate(DNN, id="linear network", noisy=True)
# Out:
# WARNING:root:Running systems in parallel. num_parallel_cpu=-1

# %%
data
# Out:
#    job_id  trial  latent_dim  embed_dim  timesteps    n        error  \
# 0       0      1           2          2         50  100    18.824460
# 0       1      1           3          3         50  100   831.634398
# 0       2      1           4          4         50  100     0.286361
# 0       3      1           5          5         50  100     0.354181
# 0       4      2           2          2         50  100     8.632804
# 0       5      2           3          3         50  100     0.524362
# 0       6      2           4          4         50  100     0.638002
# 0       7      2           5          5         50  100     7.713201
# 0       8      3           2          2         50  100     0.035780
# 0       9      3           3          3         50  100     0.986146
# 0      10      3           4          4         50  100    13.655746
# 0      11      3           5          5         50  100  3565.849079
# 0      12      4           2          2         50  100     0.256727
# 0      13      4           3          3         50  100   275.446625
# 0      14      4           4          4         50  100     0.359979
# 0      15      4           5          5         50  100     1.477259
# 0      16      5           2          2         50  100     0.146976
# 0      17      5           3          3         50  100     0.483421
# 0      18      5           4          4         50  100     0.333653
# 0      19      5           5          5         50  100   222.271145
# 0      20      6           2          2         50  100     0.470398
# 0      21      6           3          3         50  100     1.294737
# 0      22      6           4          4         50  100    51.550156
# 0      23      6           5          5         50  100     0.763225
# 0      24      7           2          2         50  100   166.509794
# 0      25      7           3          3         50  100     0.687044
# 0      26      7           4          4         50  100     0.060384
# 0      27      7           5          5         50  100     1.577170
# 0      28      8           2          2         50  100   523.507932
# 0      29      8           3          3         50  100     0.443505
# 0      30      8           4          4         50  100     0.822331
# 0      31      8           5          5         50  100     0.087219
# 0      32      9           2          2         50  100     0.274565
# 0      33      9           3          3         50  100     0.254200
# 0      34      9           4          4         50  100    39.460917
# 0      35      9           5          5         50  100    19.755772
# 0      36     10           2          2         50  100     0.232766
# 0      37     10           3          3         50  100     7.848157
# 0      38     10           4          4         50  100     2.230279
# 0      39     10           5          5         50  100     0.171401
#
#   ood_error  total_cost   duration  system_seed   algo_seed              id
# 0      None           0   3.771917    578526094  2742062416  linear network
# 0      None           0   4.475453   1668364548    24776698  linear network
# 0      None           0  22.974581   1413730242   406828641  linear network
# 0      None           0  16.468191   3966015888  2833066302  linear network
# 0      None           0   3.973581    655511433   239063218  linear network
# 0      None           0  13.955249   1762208804  2025834152  linear network
# 0      None           0  15.495584    427163208  3376051693  linear network
# 0      None           0   4.051824   3685168721  3542421140  linear network
# 0      None           0  36.325965   1361868699   505432573  linear network
# 0      None           0  18.799069   2408631046   984043747  linear network
# 0      None           0   3.354199   2048676921  3242818520  linear network
# 0      None           0   3.602292   2863077412  1752409753  linear network
# 0      None           0  38.172516   4175323686   577161997  linear network
# 0      None           0   4.886206   1949154117  1359193031  linear network
# 0      None           0  17.435983   2680519970  3127675756  linear network
# 0      None           0   6.202115   2233040973  1810886460  linear network
# 0      None           0  31.877050   1853753795  3467448586  linear network
# 0      None           0  18.252658   1808666372  3707642865  linear network
# 0      None           0  16.288697   3919208076  2851518259  linear network
# 0      None           0   4.943992   3727487839  2969688018  linear network
# 0      None           0  33.842282   1772412084  2683315832  linear network
# 0      None           0  13.906971   1360110241  1156114441  linear network
# 0      None           0   3.667505   2028042055  2748555772  linear network
# 0      None           0  13.630389   2131107623    54977239  linear network
# 0      None           0   3.645170    887695227   202800954  linear network
# 0      None           0  19.551981    411813725  2421529053  linear network
# 0      None           0  22.754150    721384697  2118232208  linear network
# 0      None           0  12.212221   2971602560  1630795547  linear network
# 0      None           0   3.430870   3169925032  3950934700  linear network
# 0      None           0  18.182397   1885899320  3935070829  linear network
# 0      None           0  15.173817    165137958  3125080588  linear network
# 0      None           0  26.642367   4053068837  2698383947  linear network
# 0      None           0  27.273822   1328989288  1164770268  linear network
# 0      None           0  23.903436   1081895235  3406319559  linear network
# 0      None           0   3.426931    465007385  3820931611  linear network
# 0      None           0   7.467828   2060305404  1307762842  linear network
# 0      None           0  19.933705   1936806103  1660694634  linear network
# 0      None           0   6.794367    153458431  2343387499  linear network
# 0      None           0  11.246959   2060926009  1938737459  linear network
# 0      None           0  15.353863   3162753142   188033504  linear network

# %%
challenge.plot(data)
# Out:
# <Axes: title={'center': 'Fixed Train Size, n=100'}, xlabel='$L$', ylabel='$\\mathcal{E}$'>
