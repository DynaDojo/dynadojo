# %%
# %load_ext autoreload
# %autoreload 2

# %%
import src.dynadojo as dd
import numpy as np
# Out:
# 2023-08-31 00:23:12.759322: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
latent_dim = 100
embed_dim = latent_dim
n = 2
timesteps = 50
system = dd.systems.HeatEquation(latent_dim, embed_dim, noise_scale=0)
x0 = system.make_init_conds_wrapper(n)
y0 = system.make_init_conds_wrapper(n, in_dist=False)
x = system.make_data_wrapper(x0, control=np.zeros((n, timesteps, embed_dim)), timesteps=timesteps)
y = system.make_data_wrapper(y0, control=np.zeros((n, timesteps, embed_dim)), timesteps=timesteps, noisy=True)
dd.utils.heat.plot(x[0], timesteps, system.dt, savefile="../graphics/heat_equation_solution.gif")
